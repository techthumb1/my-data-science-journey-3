# %% [markdown]
# # Decision Trees, Random Forest, and Gradient Boosting
# In this notebook, we explore:
# - Decision Tree classification with Gini vs Entropy
# - Random Forest ensemble method
# - Gradient Boosting with XGBoost

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
import xgboost as xgb
sns.set(style='whitegrid')

# %%
# Generate synthetic classification data
X, y = make_classification(n_samples=300, n_features=4, n_informative=3,
                           n_redundant=0, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Decision Tree

# %%
# Train and visualize a decision tree with Gini index
tree_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=42)
tree_gini.fit(X_train, y_train)

plt.figure(figsize=(10, 6))
plot_tree(tree_gini, feature_names=[f'Feature {i}' for i in range(X.shape[1])],
          class_names=['Class 0', 'Class 1'], filled=True)
plt.title('Decision Tree (Gini Index)')
plt.show()

# %%
# Evaluate decision tree
y_pred = tree_gini.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
print('\nClassification Report:\n', classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8222222222222222
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.84      0.83        45
#            1       0.84      0.80      0.82        45
#
#     accuracy                           0.82        90
#    macro avg       0.82      0.82      0.82        90
# weighted avg       0.82      0.82      0.82        90

# %% [markdown]
# ## Random Forest

# %%
# Train a random forest classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

print('Accuracy:', accuracy_score(y_test, y_pred))
print('\nClassification Report:\n', classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8777777777777778
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88        45
#            1       0.89      0.87      0.88        45
#
#     accuracy                           0.88        90
#    macro avg       0.88      0.88      0.88        90
# weighted avg       0.88      0.88      0.88        90

# %% [markdown]
# ## Gradient Boosting (XGBoost)

# %%
# Train an XGBoost classifier
xgb_clf = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_clf.fit(X_train, y_train)
y_pred = xgb_clf.predict(X_test)

print('Accuracy:', accuracy_score(y_test, y_pred))
print('\nClassification Report:\n', classification_report(y_test, y_pred))
# Out:
# /Users/jasonrobinson/my-data-science-journey-3/ds_journey_env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:33:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy: 0.8666666666666667
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87        45
#            1       0.88      0.84      0.86        45
#
#     accuracy                           0.87        90
#    macro avg       0.87      0.87      0.87        90
# weighted avg       0.87      0.87      0.87        90
